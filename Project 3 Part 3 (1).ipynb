# %%
import pandas as pd
import numpy as np
import os, time,json
import tmdbsimple as tmdb 
import sqlalchemy as db
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# # Part 1

# %%
basics_url = 'https://datasets.imdbws.com/title.basics.tsv.gz'
aka_url ='https://datasets.imdbws.com/title.akas.tsv.gz'
rating_url='https://datasets.imdbws.com/title.ratings.tsv.gz'

# %%
basics = pd.read_csv(basics_url,sep='\t', low_memory=False)
akas = pd.read_csv(aka_url,sep='\t', low_memory=False)
ratings = pd.read_csv(rating_url,sep='\t', low_memory=False)

# %%
basics=basics.replace({'\\N':np.nan}) #replace with usable null format
akas=akas.replace({'\\N':np.nan})
ratings=ratings.replace({'\\N':np.nan})

# %%
basics.head()

# %%
basics=basics.dropna(subset=['runtimeMinutes']) #drop nulls in runtime

# %%
basics=basics.dropna(subset=['genres']) #drop nulls in genres

# %%
documentary = basics['genres'].str.contains('documentary',case=False) #drop documentaries
basics = basics[~documentary]

# %%
basics=basics.loc[basics['titleType'] == 'movie'] #limit output to only movies

# %%
basics['startYear']=basics['startYear'].replace({np.nan:0}) #disregard null values
basics['startYear']=basics['startYear'].astype(object).astype(int) #convert object to int
basics=basics.loc[basics['startYear'].between(2000,2022)]

# %%
akas.head()

# %%
akas=akas.loc[akas['region'] == 'US'] #keep only US titles

# %%
akas.head()

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics['tconst'].isin(akas['titleId'])
keepers

# %%
basics = basics[keepers]
basics

# %%
keepers_rating =ratings['tconst'].isin(akas['titleId'])
ratings = ratings[keepers_rating]

# %%
# example making new folder with os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")

# %%
#basics.to_csv("Data/title_basics_resubmit.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics_resubmit.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0094859     movie                                         Chief Zabu
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                                 Chief Zabu        0       2016      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4              74                  Comedy

# %%
#akas.to_csv("Data/akas_resubmit.csv.gz",compression='gzip',index=False)

# %%
akas = pd.read_csv("Data/akas_resubmit.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
#ratings.to_csv("Data/ratings_resubmit.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
ratings = pd.read_csv("Data/ratings_resubmit.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1905
# 1  tt0000002            5.8       256
# 2  tt0000005            6.2      2518
# 3  tt0000006            5.1       173
# 4  tt0000007            5.4       783

# %%
with open('/Users/svaze/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
## Display the keys of the loaded dict
login.keys()
# Out:
# dict_keys(['api-key'])

# %%
tmdb.API_KEY =  login['api-key']

# %%
def get_movie_with_rating(movie_id):
# Get the movie object for the current id
    movie = tmdb.Movies(movie_id)
# save the .info .releases dictionaries
    movie_info = movie.info()
    releases = movie.releases()
# Loop through countries in releases
    for c in releases['countries']:
    # if the country abbreviation==US
        if c['iso_3166_1' ] =='US':
        ## save a "certification" key in the info dict with the certification
           movie_info['certification'] = c['certification']
    return movie_info

# %%
def write_json(new_data, filename): 
    """Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""    
    
    with open(filename,'r+') as file:
        # First we load existing data into a dict.
        file_data = json.load(file)
        ## Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file)

# %%
FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)

# %%
YEARS_TO_GET = [2000,2001]

# %%
# Start of OUTER loop
for YEAR in tqdm_notebook(YEARS_TO_GET,desc='YEARS',position=0):
    #Defining the JSON file to store results for year
    JSON_FILE = f'{FOLDER}tmdb_api_results_{YEAR}.json'
    # Check if file exists
    file_exists = os.path.isfile(JSON_FILE)
    # If it does not exist: create it
    if file_exists == False:
    # save an empty dict with just "imdb_id" to the new json file.
        with open(JSON_FILE,'w') as f:
            json.dump([{'imdb_id':0}],f)
    basics = pd.read_csv("Data/title_basics_resubmit.csv.gz", low_memory = False)        
    #Saving new year as the current df
    df = basics.loc[basics['startYear']==YEAR].copy()
    # saving movie ids to list
    movie_ids = df['tconst'].copy()
    # Load existing data from json into a dataframe called "previous_df"
    previous_df = pd.read_json(JSON_FILE)
    #Get index and movie id from list
    # filter out any ids that are already in the JSON_FILE
    movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]

    
    for movie_id_year in tqdm_notebook(movie_ids_to_get, desc=f'Movies from {YEAR}', position=1, leave=True):
        try:
            temp = get_movie_with_rating(movie_id_year)  
            # Append/extend results to existing file using a pre-made function
            write_json(temp,JSON_FILE)
            # Short 20 ms sleep to prevent overwhelming server
            time.sleep(0.02)
            
        # If it fails,  make a dict with just the id and None for certification.
        except Exception as e:
            continue
    final_year_df = pd.read_json(JSON_FILE)
    final_year_df.to_csv(f"{FOLDER}final_tmdb_data_{YEAR}.csv.gz", compression="gzip", index=False)

# %%
a = pd.read_csv("Data/final_tmdb_data_2000.csv.gz", low_memory = False)
a.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                homepage        id original_language  \
# 0                                   NaN       NaN               NaN
# 1                                   NaN   62127.0                en
# 2                                   NaN  110977.0                en
# 3                                   NaN  442869.0                hi
# 4  http://www.wkw-inthemoodforlove.com/     843.0                cn
#
#     original_title  ...     revenue  runtime  \
# 0              NaN  ...         NaN      NaN
# 1  The Fantasticks  ...         0.0     86.0
# 2    For the Cause  ...         0.0    100.0
# 3             Gang  ...         0.0    152.0
# 4             花樣年華  ...  12854953.0     99.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
#
#                                              tagline                 title  \
# 0                                                NaN                   NaN
# 1      Try to remember the first time magic happened       The Fantasticks
# 2       The ultimate showdown on a forbidden planet.         For the Cause
# 3                                                NaN                  Gang
# 4  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0         5.500       22.0           NaN
# 2    0.0         5.100        8.0           NaN
# 3    0.0         0.000        0.0           NaN
# 4    0.0         8.103     1948.0            PG
#
# [5 rows x 26 columns]

# %%
b = pd.read_csv("Data/final_tmdb_data_2001.csv.gz", low_memory = False)
b.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /ab5yL8zgRotrICzGbEl10z24N71.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 4   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
#
#          id original_language         original_title  ...     revenue  \
# 0       NaN               NaN                    NaN  ...         NaN
# 1   11232.0                en         Kate & Leopold  ...  76019048.0
# 2  151007.0                en       The Silent Force  ...         0.0
# 3   10696.0                en                Glitter  ...   5271666.0
# 4   17140.0                en  The Attic Expeditions  ...         0.0
#
#    runtime                                   spoken_languages    status  \
# 0      NaN                                                NaN       NaN
# 1    118.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3    104.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                  title  \
# 0                                                NaN                    NaN
# 1  If they lived in the same century they'd be pe...         Kate & Leopold
# 2  They left him for dead... They should have fin...       The Silent Force
# 3   In music she found her dream, her love, herself.                Glitter
# 4  His search for peace of mind... will leave his...  The Attic Expeditions
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0         6.317     1137.0         PG-13
# 2    0.0         5.000        3.0           NaN
# 3    0.0         4.600      117.0         PG-13
# 4    0.0         5.100       28.0             R
#
# [5 rows x 26 columns]

# %%
final_years = pd.concat([a, b], ignore_index=True, sort=False)

# %%
final_years.to_csv("Data/tmdb_results_combined.csv.gz",compression='gzip',index=False)

# %% [markdown]
# # Part 3

# %%
## create a col with a list of genres
basics['genres_split'] = basics['genres'].str.split(',')
basics
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0094859     movie                                         Chief Zabu
# ...          ...       ...                                                ...
# 82193  tt9914942     movie                             Life Without Sara Amat
# 82194  tt9915872     movie                               The Last White Witch
# 82195  tt9916170     movie                                      The Rehearsal
# 82196  tt9916190     movie                                          Safeguard
# 82197  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# 3                              The Naked Monster        0       2005      NaN
# 4                                     Chief Zabu        0       2016      NaN
# ...                                          ...      ...        ...      ...
# 82193                 La vida sense la Sara Amat        0       2019      NaN
# 82194                  My Girlfriend is a Wizard        0       2019      NaN
# 82195                                   O Ensaio        0       2019      NaN
# 82196                                  Safeguard        0       2020      NaN
# 82197                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres  \
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                  74                     Comedy
# ...               ...                        ...
# 82193              74                      Drama
# 82194              97       Comedy,Drama,Fantasy
# 82195              51                      Drama
# 82196              95  Action,Adventure,Thriller
# 82197              92              Drama,History
#
#                         genres_split
# 0         [Comedy, Fantasy, Romance]
# 1                            [Drama]
# 2                            [Drama]
# 3           [Comedy, Horror, Sci-Fi]
# 4                           [Comedy]
# ...                              ...
# 82193                        [Drama]
# 82194       [Comedy, Drama, Fantasy]
# 82195                        [Drama]
# 82196  [Action, Adventure, Thriller]
# 82197               [Drama, History]
#
# [82198 rows x 10 columns]

# %%
exploded_genres = basics.explode('genres_split')
exploded_genres
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# ...          ...       ...                                                ...
# 82196  tt9916190     movie                                          Safeguard
# 82196  tt9916190     movie                                          Safeguard
# 82196  tt9916190     movie                                          Safeguard
# 82197  tt9916362     movie                                              Coven
# 82197  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# ...                                          ...      ...        ...      ...
# 82196                                  Safeguard        0       2020      NaN
# 82196                                  Safeguard        0       2020      NaN
# 82196                                  Safeguard        0       2020      NaN
# 82197                                   Akelarre        0       2020      NaN
# 82197                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres genres_split
# 0                 118     Comedy,Fantasy,Romance       Comedy
# 0                 118     Comedy,Fantasy,Romance      Fantasy
# 0                 118     Comedy,Fantasy,Romance      Romance
# 1                  70                      Drama        Drama
# 2                 122                      Drama        Drama
# ...               ...                        ...          ...
# 82196              95  Action,Adventure,Thriller       Action
# 82196              95  Action,Adventure,Thriller    Adventure
# 82196              95  Action,Adventure,Thriller     Thriller
# 82197              92              Drama,History        Drama
# 82197              92              Drama,History      History
#
# [153558 rows x 10 columns]

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %%
title_genres = exploded_genres[['tconst','genres_split']]
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
## make new integer genre_id and drop string genres
title_genres['genre_id'] = title_genres['genres_split'].map(genre_map)
title_genres = title_genres.drop(columns='genres_split')
# Out:
# C:\Users\svaze\AppData\Local\Temp\ipykernel_25408\280659767.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   title_genres['genre_id'] = title_genres['genres_split'].map(genre_map)

# %%
genre_lookup = pd.DataFrame({'Genre Name' : genre_map.keys(),
                            'Genre ID': genre_map.values()})
genre_lookup.head()
# Out:
#   Genre Name  Genre ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
title_genres.dtypes
# Out:
# tconst      object
# genre_id     int64
# dtype: object

# %%
## get max string length
max_str_len = title_genres['tconst'].fillna('').map(len).max()

# %%
from sqlalchemy.types import *
## Calculate max string lengths for object columns
key_len = basics['tconst'].fillna('').map(len).max()
title_len = basics['primaryTitle'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "tconst": String(key_len+1), 
    "primaryTitle": Text(title_len+1),
    'startYear':Float(),
    'endYear':Float(),
    'runtimeMinutes':Integer()}

# %%
connection = "mysql+pymysql://root:root@localhost:3306/p3"
engine = db.create_engine(connection)
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/p3)

# %%
basics.to_sql('title_basics',engine,dtype=df_schema,if_exists='replace',index=False)

# %%
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %%
title_genres.to_sql('title_genres',engine,if_exists='replace',index=False)
# Out:
# 153558

# %%
tgenretest = """SELECT * FROM title_genres LIMIT 5;"""
pd.read_sql(tgenretest, engine)
# Out:
#       tconst  genre_id
# 0  tt0035423         5
# 1  tt0035423         9
# 2  tt0035423        18
# 3  tt0062336         7
# 4  tt0069049         7

# %%
genre_lookup.to_sql('genres',engine,if_exists='replace',index=False)
# Out:
# 26

# %%
genretest = """SELECT * FROM genres LIMIT 5;"""
pd.read_sql(genretest, engine)
# Out:
#   Genre Name  Genre ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
ratings.to_sql('title_ratings',engine,if_exists='replace',index=False)
# Out:
# 474546

# %%
tratingstest = """SELECT * FROM title_ratings LIMIT 5;"""
pd.read_sql(tratingstest, engine)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1905
# 1  tt0000002            5.8       256
# 2  tt0000005            6.2      2518
# 3  tt0000006            5.1       173
# 4  tt0000007            5.4       783

# %%
APIdata = a.append(b) #a = 2000 data, b= 2001 data
# Out:
# C:\Users\svaze\AppData\Local\Temp\ipykernel_25408\2192915220.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   APIdata = a.append(b)

# %%
APIdata = APIdata[['imdb_id','revenue', 'budget','certification']]

# %%
APIdata.to_sql('tmdb_data',engine,if_exists='replace',index=False)
# Out:
# 2492

# %%
tmdbtest = """SELECT * FROM tmdb_data LIMIT 5;"""
pd.read_sql(tmdbtest, engine)
# Out:
#      imdb_id     revenue      budget certification
# 0          0         NaN         NaN          None
# 1  tt0113026         0.0  10000000.0          None
# 2  tt0113092         0.0         0.0          None
# 3  tt0116391         0.0         0.0          None
# 4  tt0118694  12854953.0    150000.0            PG

# %%
q = """SHOW TABLES;""" #Show Tables in database
pd.read_sql(q, engine)
# Out:
#     Tables_in_p3
# 0         genres
# 1   title_basics
# 2   title_genres
# 3  title_ratings
# 4      tmdb_data
